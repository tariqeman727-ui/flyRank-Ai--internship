# %% [markdown]
# <a href="https://colab.research.google.com/github/tariqeman727-ui/flyRank-Ai--internship/blob/main/work/notebooks/ML_LIVE_02_Workshop_Summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-LIVE-02: Machine Learning Foundations Workshop
# ## FlyRank AI Internship – Week 2
#
# **Intern:** Eman Tariq
#
# This notebook summarizes the key concepts learned during the Machine Learning Foundations workshop and maps my Week 1 research question to an appropriate Machine Learning task.

# %% [markdown]
# # AI vs Machine Learning vs Analytics vs Rules
#
# ## Artificial Intelligence (AI)
# Artificial Intelligence is the broad field of creating systems that can perform tasks that normally require human intelligence.
#
# ## Machine Learning (ML)
# Machine Learning is a subset of AI where computers learn patterns from data instead of following manually written rules.
#
# ## Analytics
# Analytics focuses on examining data to discover insights, trends, and support decision-making.
#
# ## Rule-Based Systems
# Rule-based systems use predefined IF-THEN rules. They work well for simple and predictable problems but become less effective when data is complex or constantly changing.

# %% [markdown]
# # The Machine Learning Loop
#
# The Machine Learning workflow consists of the following steps:
#
# 1. Define the problem
# 2. Collect and prepare data
# 3. Train the model
# 4. Evaluate model performance
# 5. Improve and tune the model
# 6. Deploy and monitor the model

# %% [markdown]
# # Supervised vs Unsupervised Learning
#
# ## Supervised Learning
# - Uses labeled data.
# - Learns from input-output examples.
# - Common tasks include Classification and Regression.
#
# ## Unsupervised Learning
# - Uses unlabeled data.
# - Finds hidden patterns or groups.
# - Common task: Clustering.

# %% [markdown]
# # Generalization vs Overfitting
#
# A good Machine Learning model should generalize well to new and unseen data.
#
# Overfitting happens when a model memorizes the training data instead of learning useful patterns. Such models perform well on training data but poorly on new data.

# %% [markdown]
# # Mapping My Week 1 Search Question to an ML Task
#
# ## Week 1 Search Question
#
# Which website pages should be refreshed first to improve search engine performance?
#
# ## ML Task Type
#
# Ranking
#
# ## Why Ranking?
#
# The objective is to rank website pages according to their refresh priority so that the most important pages are updated first.
#
# ## Target
#
# Rank website pages using SEO signals such as traffic, click-through rate (CTR), rankings, and content freshness.
#
# ## Success Metric
#
# The success of the model can be measured using ranking metrics such as NDCG or by observing improvements in SEO performance after refreshing the highest-priority pages.

# %% [markdown]
# # Reflection
#
# This workshop helped me understand the differences between AI, Machine Learning, Analytics, and Rule-Based Systems. I learned the Machine Learning workflow, supervised and unsupervised learning, and the importance of generalization over overfitting. I also mapped my Week 1 search question to a Ranking Machine Learning task with a clear target and success metric.

# %%
print("ML-LIVE-02 Workshop Summary Completed Successfully!")
# Out:
# ML-LIVE-02 Workshop Summary Completed Successfully!
