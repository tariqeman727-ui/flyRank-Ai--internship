# %% [markdown]
# <a href="https://colab.research.google.com/github/tariqeman727-ui/flyRank-Ai--internship/blob/main/work/notebooks/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# I selected the Decision Tree model for this task because it is simple, easy to understand, and works well with structured tabular data. My lane is Content Refresh Prioritization, where the goal is to identify pages that should be refreshed based on features such as clicks, impressions, CTR, average position, and content age. A Decision Tree can learn patterns from these features and provides a fair comparison with the rule-based baseline created in Week 4.

# %%
print("Method Selected: Decision Tree")
print("Reason: Simple, interpretable and suitable for structured tabular data.")
# Out:
# Method Selected: Decision Tree
# Reason: Simple, interpretable and suitable for structured tabular data.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# I used the same train-test split as the Week 4 baseline to ensure a fair comparison. The model was trained on the training data and evaluated on the test data so that its performance was measured on unseen data. This makes the comparison with the baseline more reliable.

# %%
print("Train-Test Split")
print("Training data: 80%")
print("Testing data: 20%")
print("The same split is used for a fair comparison with the Week 4 baseline.")
# Out:
# Train-Test Split
# Training data: 80%
# Testing data: 20%
# The same split is used for a fair comparison with the Week 4 baseline.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
# | Model           | Data Split            | Metric         | Result                                                         |
# | --------------- | --------------------- | -------------- | -------------------------------------------------------------- |
# | Week 4 Baseline | Same train/test split | Baseline Score | Rule-based score using content age and CTR                     |
# | Decision Tree   | Same train/test split | Accuracy       | Compared against the Week 4 baseline using the same data split |

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": ["Week 4 Baseline", "Decision Tree"],
    "Data Split": ["Same train/test split", "Same train/test split"],
    "Metric": ["Baseline Score", "Accuracy"],
    "Result": [
        "Rule-based score using content age and CTR",
        "Compared against the Week 4 baseline using the same data split"
    ]
})

comparison
# Out:
#              Model             Data Split          Metric  \
# 0  Week 4 Baseline  Same train/test split  Baseline Score
# 1    Decision Tree  Same train/test split        Accuracy
#
#                                               Result
# 0         Rule-based score using content age and CTR
# 1  Compared against the Week 4 baseline using the...

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %% [markdown]
# The model may make mistakes on pages with mixed performance signals, such as high impressions but low CTR. It mainly relies on clicks, impressions, CTR, average position, and content age. The results are intended for decision-support and should be interpreted as observed patterns rather than perfect predictions.

# %%
print("Error Analysis")
print("- The model may struggle with pages that have mixed performance signals.")
print("- It mainly relies on clicks, impressions, CTR, average position and content age.")
print("- Results should be used for decision-support, not perfect prediction.")
# Out:
# Error Analysis
# - The model may struggle with pages that have mixed performance signals.
# - It mainly relies on clicks, impressions, CTR, average position and content age.
# - Results should be used for decision-support, not perfect prediction.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
